# %%
import argparse
import os, sys
import numpy as np
import math
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score

import torchvision.transforms as transforms
from torchvision.utils import save_image

from torch.utils.data import DataLoader
from torchvision import datasets
from torch.autograd import Variable
import copy
import torch.nn as nn
import torch.nn.functional as F
import torch

batch_size = 64
latent_dim = 100
n_classes = 10
img_shape = (1, 32, 32)
img_size = 32

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()

        self.label_emb = nn.Embedding(n_classes, n_classes)

        def block(in_feat, out_feat, normalize=True):
            layers = [nn.Linear(in_feat, out_feat)]
            if normalize:
                layers.append(nn.BatchNorm1d(out_feat, 0.8))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            return layers

        self.model = nn.Sequential(
            *block(latent_dim + n_classes, 128, normalize=False),
            *block(128, 256),
            *block(256, 512),
            *block(512, 1024),
            nn.Linear(1024, int(np.prod(img_shape))),
            nn.Tanh()
        )

    def forward(self, noise, labels):
        # Concatenate label embedding and image to produce input
        #print ("label: " labels)
        #print ("!!!!!!!!!!!!!!!1 ", self.label_emb(labels).size(), " ", noise.size())
        gen_input = torch.cat((self.label_emb(labels), noise), -1)
        img = self.model(gen_input)
        img = img.view(img.size(0), *img_shape)
        return img

# %%
generator = Generator()
if torch.cuda.is_available():
    print ("use cuda")
    generator = generator.cuda()
generator.load_state_dict(torch.load("models/G-180.model"))
generator.eval()
# Out:
# use cuda
# Generator(
#   (label_emb): Embedding(10, 10)
#   (model): Sequential(
#     (0): Linear(in_features=110, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace)
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): BatchNorm1d(256, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace)
#     (5): Linear(in_features=256, out_features=512, bias=True)
#     (6): BatchNorm1d(512, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace)
#     (8): Linear(in_features=512, out_features=1024, bias=True)
#     (9): BatchNorm1d(1024, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2, inplace)
#     (11): Linear(in_features=1024, out_features=1024, bias=True)
#     (12): Tanh()
#   )
# )

# %%
dataloader = torch.utils.data.DataLoader(
    datasets.MNIST(
        "../../data/mnist",
        train=True,
        download=True,
        transform=transforms.Compose(
            [transforms.Resize(img_size), transforms.ToTensor(), transforms.Normalize([0.5], [0.5])]
        ),
    ),
    batch_size=batch_size,
    shuffle=True,
)

# %%
# Unsupervised sperate the image with dropout
from skimage import data
from skimage.transform import resize


nums = 4

class predictor(nn.Module):
    def __init__(self):
        super(predictor, self).__init__()
        #self.conv1 = torch.nn.Conv2d(1, 16, 3)
        #self.conv2 = torch.nn.Conv2d(16, 8, 3)
        
        self.fc1 = torch.nn.Linear(1024, 1024)
        self.fc2 = torch.nn.Linear(1024, 512)
        self.fc3 = torch.nn.Linear(512, nums)
        self.fc4 = torch.nn.Linear(512, nums)
        self.softmax = torch.nn.Softmax(dim = 1)
    
    def forward(self, x):
        #x = F.relu(self.conv1(x))
        #x = F.relu(self.conv2(x))
        x = x.view(-1, 1024)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        #logit1 = self.fc3(x)
        #logit2 = self.fc4(x)
        #x1 = self.softmax((logit1.permute(1,0) - torch.max(logit1, dim = 1)[0]).permute(1, 0) ) #* ind1
        #x2 = self.softmax((logit2.permute(1,0) - torch.max(logit2, dim = 1)[0]).permute(1, 0) ) #* ind1
        x1 = self.softmax(self.fc3(x))
        x2 = self.softmax(self.fc4(x))
        return x1, x2

class seprator(nn.Module):
    def __init__(self):
        super(seprator, self).__init__()
        self.fc1 = torch.nn.Linear(1024, 1024)
        self.fc2 = torch.nn.Linear(1024, 512)
        self.fc3 = torch.nn.Linear(512, 512)
        self.fc4 = torch.nn.Linear(512, 100 * nums * 2)
    def forward(self, x):
#         x = x.view(-1, 1024)
#         x = 3.0 * F.tanh(self.fc1(x))
#         x = 3.0 * F.tanh(self.fc2(x))
#         x = 3.0 * F.tanh(self.fc3(x)) - 0.5
#         x = x.view(1, 10, 100)
        
        x = x.view(-1, 1024)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        #x = 3.0 * F.tanh(self.fc4(x))
        x = self.fc4(x)
        x = x.view(-1, 2, nums, 100)
        
        return x
    
def entropy(x):
    return torch.mean(-torch.sum(x * torch.log(x + 1e-9), dim = 1), dim = 0)

def show_sudoku(x1, x2, x_mix, name="1"):
    n_col = 4
    n_row = 4
    fig, axes = plt.subplots(n_row, n_col * 3, figsize = (3 *n_col, n_row))
    for j in range(4):
        for k in range(4):
            axes[j][k].imshow(x1[j][k], cmap = "gray")
            axes[j][k].set_axis_off()
            axes[j][4 + k].imshow(x2[j][k], cmap="gray")
            axes[j][4 + k].set_axis_off()
            axes[j][8 + k].imshow(x_mix[j][k], cmap="gray")
            axes[j][8 + k].set_axis_off()
            """
            fig2, ax = plt.subplots(1,1, figsize = (1, 1))
            ax.imshow(x1[j][k], cmap = "gray")
            ax.set_axis_off()
            fig2.savefig('figs/%s_1_%d_%d.png'%(name, j, k), transparent = True, bbox_inches = 'tight', pad_inches = 0)
            
            ax.imshow(x2[j][k], cmap = "gray")
            ax.set_axis_off()
            fig2.savefig('figs/%s_2_%d_%d.png'%(name, j, k), transparent = True, bbox_inches = 'tight', pad_inches = 0)
            
            ax.imshow(x_mix[j][k], cmap = "gray")
            ax.set_axis_off()
            fig2.savefig('figs/%s_3_%d_%d.png'%(name, j, k), transparent = True, bbox_inches = 'tight', pad_inches = 0)
            """
            
    #plt.axis("off")
    plt.show()

def gen_alldiff_constraints(nums, batch_size):
    
    sqr_nums = int(np.sqrt(nums))
    idx = np.arange(nums**2).reshape(nums, nums)
    all_diffs = []
    for bs in range(batch_size):
        all_diff = []
        for i in range(nums):
            all_diff.append(idx[:,i])

        for i in range(nums):
            all_diff.append(idx[i,:])

        for i in range(sqr_nums):
            for j in range(sqr_nums):
                all_diff.append(idx[i*sqr_nums:(i+1)*sqr_nums, j*sqr_nums:(j+1)*sqr_nums].reshape(-1))
        all_diff = np.asarray(all_diff, dtype="int32")
        all_diff += bs * (nums**2)
        all_diffs.append(all_diff)

    all_diffs = np.concatenate(all_diffs, axis = 0)
    return all_diffs

def not_sudoku(l12):
    l12 = np.asarray(l12)
    nums = int(np.sqrt(l12.shape[0]))
    l12 = l12.reshape(nums, nums, 2)
    #print(l12.shape)
    for i in range(nums):
        if (len(list(set(l12[i].reshape(-1)))) < 2 * nums):
            return True
        if (len(list(set(l12[:,i].reshape(-1)))) < 2 * nums):
            return True
    sqrnums = int(np.sqrt(nums))
    for i in range(sqrnums):
        for j in range(sqrnums):
            if (len(list(set(l12[i*sqrnums:(i+1)*sqrnums, j*sqrnums:(j+1)*sqrnums, :].reshape(-1)))) < 2 * nums):
                return True
    return False

def save_model(model, path):
    torch.save(model.state_dict(), path)
def load_model(model, path):
    model.load_state_dict(torch.load(path))
    model.eval()


pred_load_path = "./models/pred.model-9992"
sep_load_path = "./models/sep.model-9992"

pred_save_path = "./models/pred-new.model"
sep_save_path = "./models/sep-new.model"



sudoku = np.load("../../../4by4.npy") #100, 16, 1, 28, 28
sudoku5678 = np.load("../../../4by4_5678.npy") #100, 16, 1, 28, 28
ori_label = np.load("../../../4by4_labels.npy") #100, 16
ori_label5678 = np.load("../../../4by4_5678_labels.npy") #100, 16

n_data = sudoku.shape[0]
#idx1, idx2 = 2, 31.0

use_cuda = torch.cuda.is_available()

#print ("Initial Image")
n_col = 4
n_row = 4
#show_sudoku(s1, s2, s_mix, "s1")
lr = 0.0001
printdrop_out__every = 1

sep  = seprator()
pred = predictor()
if use_cuda:
    sep = sep.cuda()
    pred = pred.cuda()
    print("use_cuda")

if (os.path.isfile(pred_load_path) and os.path.isfile(sep_load_path)):
    print("loading from old-models")
    load_model(sep, sep_load_path)
    load_model(pred, pred_load_path)
    


base1 = 1
base2 = 5

idx_lst = np.arange(n_data)
#idx_lst = np.load("unsolved.npy")
#idx_lst = np.arange(n_data)

batch_size = 10
check_freq = 100


s_mix_lst = []
l1_lst = []
l2_lst = []
s1_lst = []
s2_lst = []

alldiff_constraints = gen_alldiff_constraints(nums, batch_size) #bs * 12 * 4

if use_cuda:
    gen_labels = torch.LongTensor(np.arange(nums**3 * 2 * batch_size, dtype = "int32") % (2*nums) + base1).cuda()
else:
    gen_labels = torch.LongTensor(np.arange(nums**3 * 2 * batch_size, dtype = "int32") % (2*nums) + base1)
    
print("Training Starts")
unsolved = []
for _epoch_ in range(10000):
    all_sudoku_acc = 0
    all_label_acc = 0
    all_recon_loss = 0
    all_entropy_loss = 0
    all_alldiff_loss = 0
    cnt = 0
    for idx in idx_lst:
        #idx = 145
        s1 = sudoku[idx]
        s2 = sudoku5678[idx]
        
        l1 = ori_label[idx]
        l2 = ori_label5678[idx]
        
        s1 = s1.reshape(nums, nums, 32, 32)
        s2 = s2.reshape(nums, nums, 32, 32)
        s_mix = np.maximum(s1, s2)
    
        s_mix = np.reshape(s_mix, (16, 1, 32, 32))
        
        #loading samples
        s_mix_lst.append(s_mix)
        l1_lst.append(l1)
        l2_lst.append(l2)
        s1_lst.append(s1)
        s2_lst.append(s2)
        
        if (len(s_mix_lst) == batch_size):
            s_mix = np.concatenate(s_mix_lst, axis = 0) # bs * 16, 1, 32, 32
            s_mix = Variable(torch.tensor(s_mix).float(), requires_grad=False)

            if use_cuda:
                s_mix = s_mix.cuda()
                
            #print ("Initial Image")
            #show_sudoku(s1_lst[0], s2_lst[0], np.reshape(s_mix_lst[0], (4, 4, 32, 32)), "s1")
            
            epochs = 1
            for ii in range(epochs):
                
                labels1_distribution, labels2_distribution = pred(s_mix) #bs * 16, 4 

                if (use_cuda):
                    z = sep(torch.tensor(s_mix.reshape(-1, 1, 32, 32)).float()).cuda() #bs * 16, 2, 4, 100
                else:
                    z = sep(torch.tensor(s_mix.reshape(-1, 1, 32, 32)).float())

                optimizer = torch.optim.Adam(list(pred.parameters()) + list(sep.parameters()), lr=lr)
                
                # compute accs
                labels1 = labels1_distribution.cpu().data.numpy()
                labels2 = labels2_distribution.cpu().data.numpy()
                
                labels1_argmax = np.argmax(labels1, axis=1)
                labels2_argmax = np.argmax(labels2, axis=1)

                labels12 = np.concatenate([(labels1_argmax + base1).reshape(-1, 1), (labels2_argmax + base2).reshape(-1, 1)], axis = 1)
                
                l1 = np.concatenate(l1_lst, axis = 0)
                l2 = np.concatenate(l2_lst, axis = 0)
                
                l12 = np.concatenate([l1.reshape(-1, 1), l2.reshape(-1, 1)], axis = 1) # bs * 16, 2
                
                
                eqn = np.equal(labels12, l12).astype("int").reshape(batch_size, nums**2, 2)
                
                label_acc = np.mean((np.sum(eqn, axis = 2) == 2).astype("float32"))
                sudoku_acc = np.mean((np.sum(eqn, axis = (1,2)) == 32).astype("float32"))
                
                
                for i in range(batch_size):
                    if (not_sudoku(labels12[i*nums**2:(i+1)*nums**2])):
                        unsolved.append(i + idx - batch_size + 1)
                # compute mixture


                gen_imgs = generator(z.view(-1, 100), gen_labels) #bs*16*2*4, 1, 32, 32

                label_distribution = torch.cat([labels1_distribution, labels2_distribution], dim = 1) # bs * 16 * 8

                gen_mix = gen_imgs.permute(1, 2, 3, 0) * label_distribution.view(-1)

                gen_mix = gen_mix.view(1, 32, 32, batch_size * 16, 2, 4)

                gen_mix = torch.sum(gen_mix, dim = 5) # avg by distribution 1, 32, 32, bs*16, 2

                gen_img_demix = gen_mix.permute(3, 4, 0, 1, 2) # bs*16, 2, 32, 32 #only used for visualization

                gen_mix = torch.max(gen_mix, dim = 4)[0]

                gen_mix = gen_mix.permute(3, 0, 1, 2).view(-1, 32, 32) #bs * 16, 32, 32

                cri = torch.nn.L1Loss()

                loss_recon = 0.

                loss_recon = cri(s_mix.view(-1, 32, 32), gen_mix)

                loss_recon /= (1.0 * labels1_distribution.size(0))

                entropy_cell = 0.5 * (entropy(labels1_distribution) + entropy(labels2_distribution))
                
                all_diff_loss1 = entropy(torch.mean(labels1_distribution[torch.LongTensor(alldiff_constraints)], dim = 1))
                all_diff_loss2 = entropy(torch.mean(labels2_distribution[torch.LongTensor(alldiff_constraints)], dim = 1))
                entropy_alldiff = 0.5 * (all_diff_loss1 + all_diff_loss2) 

                scale_recon = 0.001

                keep_p = 1.0

                drop_out_recon = torch.nn.Dropout(p = 1.0 - keep_p)
                drop_out_cell = torch.nn.Dropout(p = 1.0 - 1.0)
                drop_out_alldiff = torch.nn.Dropout(p = 1.0 - 1.0)


                loss_recon = drop_out_recon(loss_recon)
                entropy_cell_drop = drop_out_cell(entropy_cell)
                entropy_alldiff_drop = drop_out_alldiff(entropy_alldiff)

                if (_epoch_ < 0):
                    loss = scale_recon * loss_recon
                else:
                    #loss = scale_recon * loss_recon
                    loss = scale_recon * loss_recon + 0.01 * entropy_cell_drop - 1.0 * (entropy_alldiff_drop)
            
                optimizer.zero_grad()
                loss.backward(retain_graph=True)
                optimizer.step()

                if (ii % 100 == 0 and scale_recon * loss_recon.item() < 0.085): #  #and sudoku_acc != 1.0 #(cnt + 1) % check_freq == 0 #
                    print ("puzzle-%d, Iteration %d: total_loss: %f, loss_recon: %f, entropy_cell: %f, entropy_alldiff: %f"% (idx, ii, loss.item(), scale_recon * loss_recon.item(), entropy_cell.item(),  entropy_alldiff.item()))
                    print ("epoch = %d, iter-%d, label_acc = %f, sudoku_acc= %f" % (_epoch_, ii, label_acc, sudoku_acc))

                    for i in range(4):
                        for j in range(4):
                            print(labels1_argmax[i*4 + j] + base1, end = ",")
                        print(" ", end = "")

                        for j in range(4):
                            print(labels2_argmax[i*4 + j] + base2, end = ",")
                        print(" ", end = "")

                        for j in range(4):
                            print(l1[i*4 + j], end = ",")
                        print(" ", end = "")

                        for j in range(4):
                            print(l2[i*4 + j], end = ",")
                        print("")
                    
                    print ("Initial Image")
                    show_sudoku(s1_lst[0], s2_lst[0], np.reshape(s_mix_lst[0], (4, 4, 32, 32)), "init")
                    gen_imgs1_numpy = np.concatenate([item.cpu().data.numpy() for item in gen_img_demix[:nums**2,0]])
                    gen_imgs1_numpy = np.reshape(gen_imgs1_numpy, (4, 4, 32, 32))

                    gen_imgs2_numpy = np.concatenate([item.cpu().data.numpy() for item in gen_img_demix[:nums**2,1]])
                    gen_imgs2_numpy = np.reshape(gen_imgs2_numpy, (4, 4, 32, 32))

                    gen_mix_numpy = np.concatenate([item.cpu().data.numpy() for item in gen_mix[:nums**2]])
                    gen_mix_numpy = np.reshape(gen_mix_numpy, (4, 4, 32, 32))
                    
                    show_sudoku(gen_imgs1_numpy, gen_imgs2_numpy, gen_mix_numpy, "recon")
                    
            
            s_mix_lst = []
            l1_lst = []
            l2_lst = []
            s1_lst = []
            s2_lst = []
                 
            all_label_acc += label_acc
            all_sudoku_acc += sudoku_acc
            all_entropy_loss += entropy_cell.item()
            all_alldiff_loss += entropy_alldiff.item()
            all_recon_loss += scale_recon * loss_recon.item()
            
            cnt += 1
            #print(cnt)
            if (cnt % check_freq == 0):

                #print ("Initial Image")
                #show_sudoku(s1, s2, np.reshape(s_mix, (4, 4, 32, 32)), "s1")

                print("#puzzle = %d, sudoku_acc = %f, label_acc = %f, entropy_loss = %f, alldiff_loss = %f, recon_loss = %f"\
                      %(cnt * batch_size, all_sudoku_acc/cnt, all_label_acc/cnt, all_entropy_loss/cnt, all_alldiff_loss/cnt, all_recon_loss/cnt))
                #save_model(pred, pred_save_path)
                #save_model(sep, sep_save_path)

                cnt = 0
                all_label_acc = 0
                all_sudoku_acc = 0
                all_recon_loss = 0
                all_entropy_loss = 0
                all_alldiff_loss = 0

print(len(unsolved))
print(unsolved)
np.save("unsolved", unsolved)
# Out:
# use_cuda
# loading from old-models
# Training Starts
# puzzle-99, Iteration 0: total_loss: -1.306430, loss_recon: 0.079865, entropy_cell: 0.000000, entropy_alldiff: 1.386295
# epoch = 0, iter-0, label_acc = 1.000000, sudoku_acc= 1.000000
# 2,4,1,3, 7,8,5,6, 2,4,1,3, 7,8,5,6,
# 1,3,2,4, 5,6,8,7, 1,3,2,4, 5,6,8,7,
# 4,1,3,2, 6,5,7,8, 4,1,3,2, 6,5,7,8,
# 3,2,4,1, 8,7,6,5, 3,2,4,1, 8,7,6,5,
# Initial Image
# puzzle-439, Iteration 0: total_loss: -1.306860, loss_recon: 0.079436, entropy_cell: 0.000000, entropy_alldiff: 1.386295
# epoch = 0, iter-0, label_acc = 1.000000, sudoku_acc= 1.000000
# 1,4,2,3, 7,6,8,5, 1,4,2,3, 7,6,8,5,
# 3,2,4,1, 8,5,6,7, 3,2,4,1, 8,5,6,7,
# 2,3,1,4, 5,8,7,6, 2,3,1,4, 5,8,7,6,
# 4,1,3,2, 6,7,5,8, 4,1,3,2, 6,7,5,8,
# Initial Image
# #puzzle = 1000, sudoku_acc = 1.000000, label_acc = 1.000000, entropy_loss = 0.000000, alldiff_loss = 1.386295, recon_loss = 0.083005
# #puzzle = 1000, sudoku_acc = 1.000000, label_acc = 1.000000, entropy_loss = 0.000000, alldiff_loss = 1.386295, recon_loss = 0.083555
# puzzle-2729, Iteration 0: total_loss: -1.307843, loss_recon: 0.078452, entropy_cell: 0.000000, entropy_alldiff: 1.386295
# epoch = 0, iter-0, label_acc = 1.000000, sudoku_acc= 1.000000
# 2,4,1,3, 7,6,8,5, 2,4,1,3, 7,6,8,5,
# 3,1,2,4, 5,8,6,7, 3,1,2,4, 5,8,6,7,
# 4,2,3,1, 8,5,7,6, 4,2,3,1, 8,5,7,6,
# 1,3,4,2, 6,7,5,8, 1,3,4,2, 6,7,5,8,
# Initial Image
# #puzzle = 1000, sudoku_acc = 0.999000, label_acc = 0.999875, entropy_loss = 0.000033, alldiff_loss = 1.386278, recon_loss = 0.083640
# #puzzle = 1000, sudoku_acc = 0.998000, label_acc = 0.999875, entropy_loss = 0.000000, alldiff_loss = 1.386209, recon_loss = 0.083719
# puzzle-4169, Iteration 0: total_loss: -1.307277, loss_recon: 0.079018, entropy_cell: 0.000000, entropy_alldiff: 1.386295
# epoch = 0, iter-0, label_acc = 1.000000, sudoku_acc= 1.000000
# 3,4,1,2, 8,5,7,6, 3,4,1,2, 8,5,7,6,
# 2,1,4,3, 6,7,5,8, 2,1,4,3, 6,7,5,8,
# 4,3,2,1, 5,6,8,7, 4,3,2,1, 5,6,8,7,
# 1,2,3,4, 7,8,6,5, 1,2,3,4, 7,8,6,5,
# Initial Image
# #puzzle = 1000, sudoku_acc = 0.999000, label_acc = 0.999937, entropy_loss = 0.000000, alldiff_loss = 1.386252, recon_loss = 0.084012
# #puzzle = 1000, sudoku_acc = 1.000000, label_acc = 1.000000, entropy_loss = 0.000000, alldiff_loss = 1.386295, recon_loss = 0.083846
# #puzzle = 1000, sudoku_acc = 0.999000, label_acc = 0.999937, entropy_loss = 0.000000, alldiff_loss = 1.386252, recon_loss = 0.084162
# #puzzle = 1000, sudoku_acc = 1.000000, label_acc = 1.000000, entropy_loss = 0.000000, alldiff_loss = 1.386295, recon_loss = 0.084010
# #puzzle = 1000, sudoku_acc = 0.999000, label_acc = 0.999937, entropy_loss = 0.000000, alldiff_loss = 1.386252, recon_loss = 0.084255
# #puzzle = 1000, sudoku_acc = 0.998000, label_acc = 0.999875, entropy_loss = 0.000000, alldiff_loss = 1.386209, recon_loss = 0.083986
# #puzzle = 1000, sudoku_acc = 1.000000, label_acc = 1.000000, entropy_loss = 0.000000, alldiff_loss = 1.386295, recon_loss = 0.083856
# #puzzle = 1000, sudoku_acc = 1.000000, label_acc = 1.000000, entropy_loss = 0.000000, alldiff_loss = 1.386295, recon_loss = 0.084225
# puzzle-2729, Iteration 0: total_loss: -1.307693, loss_recon: 0.078602, entropy_cell: 0.000000, entropy_alldiff: 1.386295
# epoch = 1, iter-0, label_acc = 1.000000, sudoku_acc= 1.000000
# 2,4,1,3, 7,6,8,5, 2,4,1,3, 7,6,8,5,
# 3,1,2,4, 5,8,6,7, 3,1,2,4, 5,8,6,7,
# 4,2,3,1, 8,5,7,6, 4,2,3,1, 8,5,7,6,
# 1,3,4,2, 6,7,5,8, 1,3,4,2, 6,7,5,8,
# Initial Image
# #puzzle = 1000, sudoku_acc = 0.999000, label_acc = 0.999875, entropy_loss = 0.000000, alldiff_loss = 1.386238, recon_loss = 0.084157
# #puzzle = 1000, sudoku_acc = 0.998000, label_acc = 0.999875, entropy_loss = 0.000000, alldiff_loss = 1.386209, recon_loss = 0.084096
# puzzle-4169, Iteration 0: total_loss: -1.306481, loss_recon: 0.079815, entropy_cell: 0.000000, entropy_alldiff: 1.386295
# epoch = 1, iter-0, label_acc = 1.000000, sudoku_acc= 1.000000
# 3,4,1,2, 8,5,7,6, 3,4,1,2, 8,5,7,6,
# 2,1,4,3, 6,7,5,8, 2,1,4,3, 6,7,5,8,
# 4,3,2,1, 5,6,8,7, 4,3,2,1, 5,6,8,7,
# 1,2,3,4, 7,8,6,5, 1,2,3,4, 7,8,6,5,
# Initial Image
# #puzzle = 1000, sudoku_acc = 0.999000, label_acc = 0.999937, entropy_loss = 0.000000, alldiff_loss = 1.386252, recon_loss = 0.084382
# #puzzle = 1000, sudoku_acc = 1.000000, label_acc = 1.000000, entropy_loss = 0.000000, alldiff_loss = 1.386295, recon_loss = 0.084143
# #puzzle = 1000, sudoku_acc = 0.999000, label_acc = 0.999937, entropy_loss = 0.000000, alldiff_loss = 1.386252, recon_loss = 0.084426
# puzzle-7039, Iteration 0: total_loss: -1.306540, loss_recon: 0.079755, entropy_cell: 0.000000, entropy_alldiff: 1.386295
# epoch = 1, iter-0, label_acc = 1.000000, sudoku_acc= 1.000000
# 2,4,3,1, 8,5,7,6, 2,4,3,1, 8,5,7,6,
# 3,1,2,4, 6,7,5,8, 3,1,2,4, 6,7,5,8,
# 4,2,1,3, 7,8,6,5, 4,2,1,3, 7,8,6,5,
# 1,3,4,2, 5,6,8,7, 1,3,4,2, 5,6,8,7,
# Initial Image
# puzzle-7109, Iteration 0: total_loss: -1.306549, loss_recon: 0.079746, entropy_cell: 0.000000, entropy_alldiff: 1.386295
# epoch = 1, iter-0, label_acc = 1.000000, sudoku_acc= 1.000000
# 2,1,3,4, 7,6,5,8, 2,1,3,4, 7,6,5,8,
# 4,3,1,2, 5,8,7,6, 4,3,1,2, 5,8,7,6,
# 3,2,4,1, 8,5,6,7, 3,2,4,1, 8,5,6,7,
# 1,4,2,3, 6,7,8,5, 1,4,2,3, 6,7,8,5,
# Initial Image
# #puzzle = 1000, sudoku_acc = 1.000000, label_acc = 1.000000, entropy_loss = 0.000000, alldiff_loss = 1.386295, recon_loss = 0.084233
# #puzzle = 1000, sudoku_acc = 0.999000, label_acc = 0.999937, entropy_loss = 0.000000, alldiff_loss = 1.386252, recon_loss = 0.084439
# #puzzle = 1000, sudoku_acc = 0.998000, label_acc = 0.999875, entropy_loss = 0.000000, alldiff_loss = 1.386209, recon_loss = 0.084109
# #puzzle = 1000, sudoku_acc = 1.000000, label_acc = 1.000000, entropy_loss = 0.000000, alldiff_loss = 1.386295, recon_loss = 0.083891
# #puzzle = 1000, sudoku_acc = 1.000000, label_acc = 1.000000, entropy_loss = 0.000000, alldiff_loss = 1.386295, recon_loss = 0.083948
# puzzle-2729, Iteration 0: total_loss: -1.307913, loss_recon: 0.078382, entropy_cell: 0.000000, entropy_alldiff: 1.386295
# epoch = 2, iter-0, label_acc = 1.000000, sudoku_acc= 1.000000
# 2,4,1,3, 7,6,8,5, 2,4,1,3, 7,6,8,5,
# 3,1,2,4, 5,8,6,7, 3,1,2,4, 5,8,6,7,
# 4,2,3,1, 8,5,7,6, 4,2,3,1, 8,5,7,6,
# 1,3,4,2, 6,7,5,8, 1,3,4,2, 6,7,5,8,
# Initial Image
# #puzzle = 1000, sudoku_acc = 0.999000, label_acc = 0.999812, entropy_loss = 0.000038, alldiff_loss = 1.386279, recon_loss = 0.083816
# #puzzle = 1000, sudoku_acc = 0.998000, label_acc = 0.999875, entropy_loss = 0.000000, alldiff_loss = 1.386209, recon_loss = 0.083873
# puzzle-4169, Iteration 0: total_loss: -1.306538, loss_recon: 0.079757, entropy_cell: 0.000000, entropy_alldiff: 1.386295
# epoch = 2, iter-0, label_acc = 1.000000, sudoku_acc= 1.000000
# 3,4,1,2, 8,5,7,6, 3,4,1,2, 8,5,7,6,
# 2,1,4,3, 6,7,5,8, 2,1,4,3, 6,7,5,8,
# 4,3,2,1, 5,6,8,7, 4,3,2,1, 5,6,8,7,
# 1,2,3,4, 7,8,6,5, 1,2,3,4, 7,8,6,5,
# Initial Image
# #puzzle = 1000, sudoku_acc = 0.999000, label_acc = 0.999937, entropy_loss = 0.000000, alldiff_loss = 1.386252, recon_loss = 0.084184
# #puzzle = 1000, sudoku_acc = 1.000000, label_acc = 1.000000, entropy_loss = 0.000000, alldiff_loss = 1.386295, recon_loss = 0.083908
# puzzle-6399, Iteration 0: total_loss: -1.306408, loss_recon: 0.079887, entropy_cell: 0.000000, entropy_alldiff: 1.386295
# epoch = 2, iter-0, label_acc = 1.000000, sudoku_acc= 1.000000
# 3,2,1,4, 8,7,5,6, 3,2,1,4, 8,7,5,6,
# 1,4,3,2, 6,5,7,8, 1,4,3,2, 6,5,7,8,
# 4,1,2,3, 5,8,6,7, 4,1,2,3, 5,8,6,7,
# 2,3,4,1, 7,6,8,5, 2,3,4,1, 7,6,8,5,
# Initial Image
# #puzzle = 1000, sudoku_acc = 0.999000, label_acc = 0.999937, entropy_loss = 0.000000, alldiff_loss = 1.386252, recon_loss = 0.084395
# #puzzle = 1000, sudoku_acc = 1.000000, label_acc = 1.000000, entropy_loss = 0.000000, alldiff_loss = 1.386295, recon_loss = 0.084131
# #puzzle = 1000, sudoku_acc = 0.999000, label_acc = 0.999937, entropy_loss = 0.000000, alldiff_loss = 1.386252, recon_loss = 0.084398
# #puzzle = 1000, sudoku_acc = 0.998000, label_acc = 0.999875, entropy_loss = 0.000000, alldiff_loss = 1.386209, recon_loss = 0.084176
# #puzzle = 1000, sudoku_acc = 1.000000, label_acc = 1.000000, entropy_loss = 0.000000, alldiff_loss = 1.386295, recon_loss = 0.083945
# #puzzle = 1000, sudoku_acc = 1.000000, label_acc = 1.000000, entropy_loss = 0.000000, alldiff_loss = 1.386295, recon_loss = 0.084298
# puzzle-2729, Iteration 0: total_loss: -1.307457, loss_recon: 0.078838, entropy_cell: 0.000000, entropy_alldiff: 1.386295
# epoch = 3, iter-0, label_acc = 1.000000, sudoku_acc= 1.000000
# 2,4,1,3, 7,6,8,5, 2,4,1,3, 7,6,8,5,
# 3,1,2,4, 5,8,6,7, 3,1,2,4, 5,8,6,7,
# 4,2,3,1, 8,5,7,6, 4,2,3,1, 8,5,7,6,
# 1,3,4,2, 6,7,5,8, 1,3,4,2, 6,7,5,8,
# Initial Image
# #puzzle = 1000, sudoku_acc = 0.999000, label_acc = 0.999937, entropy_loss = 0.000011, alldiff_loss = 1.386252, recon_loss = 0.084219
# #puzzle = 1000, sudoku_acc = 0.998000, label_acc = 0.999875, entropy_loss = 0.000000, alldiff_loss = 1.386209, recon_loss = 0.084089
# puzzle-4169, Iteration 0: total_loss: -1.306336, loss_recon: 0.079959, entropy_cell: 0.000000, entropy_alldiff: 1.386295
# epoch = 3, iter-0, label_acc = 1.000000, sudoku_acc= 1.000000
# 3,4,1,2, 8,5,7,6, 3,4,1,2, 8,5,7,6,
# 2,1,4,3, 6,7,5,8, 2,1,4,3, 6,7,5,8,
# 4,3,2,1, 5,6,8,7, 4,3,2,1, 5,6,8,7,
# 1,2,3,4, 7,8,6,5, 1,2,3,4, 7,8,6,5,
# Initial Image
# #puzzle = 1000, sudoku_acc = 0.999000, label_acc = 0.999937, entropy_loss = 0.000000, alldiff_loss = 1.386252, recon_loss = 0.084417
# #puzzle = 1000, sudoku_acc = 1.000000, label_acc = 1.000000, entropy_loss = 0.000000, alldiff_loss = 1.386295, recon_loss = 0.084143
# #puzzle = 1000, sudoku_acc = 0.999000, label_acc = 0.999937, entropy_loss = 0.000000, alldiff_loss = 1.386252, recon_loss = 0.084449
# #puzzle = 1000, sudoku_acc = 1.000000, label_acc = 1.000000, entropy_loss = 0.000000, alldiff_loss = 1.386295, recon_loss = 0.084212
# #puzzle = 1000, sudoku_acc = 0.999000, label_acc = 0.999937, entropy_loss = 0.000000, alldiff_loss = 1.386252, recon_loss = 0.084509
# puzzle-9729, Iteration 0: total_loss: -1.306368, loss_recon: 0.079927, entropy_cell: 0.000000, entropy_alldiff: 1.386295
# epoch = 3, iter-0, label_acc = 1.000000, sudoku_acc= 1.000000
# 3,1,2,4, 7,5,6,8, 3,1,2,4, 7,5,6,8,
# 4,2,3,1, 8,6,5,7, 4,2,3,1, 8,6,5,7,
# 2,4,1,3, 6,8,7,5, 2,4,1,3, 6,8,7,5,
# 1,3,4,2, 5,7,8,6, 1,3,4,2, 5,7,8,6,
# Initial Image
# #puzzle = 1000, sudoku_acc = 0.998000, label_acc = 0.999875, entropy_loss = 0.000000, alldiff_loss = 1.386209, recon_loss = 0.084226
# #puzzle = 1000, sudoku_acc = 1.000000, label_acc = 1.000000, entropy_loss = 0.000000, alldiff_loss = 1.386295, recon_loss = 0.084016
# #puzzle = 1000, sudoku_acc = 1.000000, label_acc = 1.000000, entropy_loss = 0.000000, alldiff_loss = 1.386295, recon_loss = 0.084006
# puzzle-2729, Iteration 0: total_loss: -1.308115, loss_recon: 0.078181, entropy_cell: 0.000000, entropy_alldiff: 1.386295
# epoch = 4, iter-0, label_acc = 1.000000, sudoku_acc= 1.000000
# 2,4,1,3, 7,6,8,5, 2,4,1,3, 7,6,8,5,
# 3,1,2,4, 5,8,6,7, 3,1,2,4, 5,8,6,7,
# 4,2,3,1, 8,5,7,6, 4,2,3,1, 8,5,7,6,
# 1,3,4,2, 6,7,5,8, 1,3,4,2, 6,7,5,8,
# Initial Image
# #puzzle = 1000, sudoku_acc = 0.999000, label_acc = 0.999812, entropy_loss = 0.000015, alldiff_loss = 1.386257, recon_loss = 0.083980
# #puzzle = 1000, sudoku_acc = 0.998000, label_acc = 0.999875, entropy_loss = 0.000000, alldiff_loss = 1.386209, recon_loss = 0.083942
# puzzle-4169, Iteration 0: total_loss: -1.306408, loss_recon: 0.079887, entropy_cell: 0.000000, entropy_alldiff: 1.386295
# epoch = 4, iter-0, label_acc = 1.000000, sudoku_acc= 1.000000
# 3,4,1,2, 8,5,7,6, 3,4,1,2, 8,5,7,6,
# 2,1,4,3, 6,7,5,8, 2,1,4,3, 6,7,5,8,
# 4,3,2,1, 5,6,8,7, 4,3,2,1, 5,6,8,7,
# 1,2,3,4, 7,8,6,5, 1,2,3,4, 7,8,6,5,
# Initial Image
# #puzzle = 1000, sudoku_acc = 0.999000, label_acc = 0.999937, entropy_loss = 0.000000, alldiff_loss = 1.386252, recon_loss = 0.084203
# #puzzle = 1000, sudoku_acc = 1.000000, label_acc = 1.000000, entropy_loss = 0.000000, alldiff_loss = 1.386295, recon_loss = 0.084050
# #puzzle = 1000, sudoku_acc = 0.999000, label_acc = 0.999937, entropy_loss = 0.000000, alldiff_loss = 1.386252, recon_loss = 0.084354
# puzzle-7039, Iteration 0: total_loss: -1.306360, loss_recon: 0.079935, entropy_cell: 0.000000, entropy_alldiff: 1.386295
# epoch = 4, iter-0, label_acc = 1.000000, sudoku_acc= 1.000000
# 2,4,3,1, 8,5,7,6, 2,4,3,1, 8,5,7,6,
# 3,1,2,4, 6,7,5,8, 3,1,2,4, 6,7,5,8,
# 4,2,1,3, 7,8,6,5, 4,2,1,3, 7,8,6,5,
# 1,3,4,2, 5,6,8,7, 1,3,4,2, 5,6,8,7,
# Initial Image
# puzzle-7109, Iteration 0: total_loss: -1.306352, loss_recon: 0.079943, entropy_cell: 0.000000, entropy_alldiff: 1.386295
# epoch = 4, iter-0, label_acc = 1.000000, sudoku_acc= 1.000000
# 2,1,3,4, 7,6,5,8, 2,1,3,4, 7,6,5,8,
# 4,3,1,2, 5,8,7,6, 4,3,1,2, 5,8,7,6,
# 3,2,4,1, 8,5,6,7, 3,2,4,1, 8,5,6,7,
# 1,4,2,3, 6,7,8,5, 1,4,2,3, 6,7,8,5,
# Initial Image
# #puzzle = 1000, sudoku_acc = 1.000000, label_acc = 1.000000, entropy_loss = 0.000000, alldiff_loss = 1.386295, recon_loss = 0.084107
# #puzzle = 1000, sudoku_acc = 0.999000, label_acc = 0.999937, entropy_loss = 0.000000, alldiff_loss = 1.386252, recon_loss = 0.084422
# #puzzle = 1000, sudoku_acc = 0.998000, label_acc = 0.999875, entropy_loss = 0.000000, alldiff_loss = 1.386209, recon_loss = 0.084193
# #puzzle = 1000, sudoku_acc = 1.000000, label_acc = 1.000000, entropy_loss = 0.000000, alldiff_loss = 1.386295, recon_loss = 0.084106
# #puzzle = 1000, sudoku_acc = 1.000000, label_acc = 1.000000, entropy_loss = 0.000000, alldiff_loss = 1.386295, recon_loss = 0.084209
# puzzle-2729, Iteration 0: total_loss: -1.307617, loss_recon: 0.078679, entropy_cell: 0.000000, entropy_alldiff: 1.386295
# epoch = 5, iter-0, label_acc = 1.000000, sudoku_acc= 1.000000
# 2,4,1,3, 7,6,8,5, 2,4,1,3, 7,6,8,5,
# 3,1,2,4, 5,8,6,7, 3,1,2,4, 5,8,6,7,
# 4,2,3,1, 8,5,7,6, 4,2,3,1, 8,5,7,6,
# 1,3,4,2, 6,7,5,8, 1,3,4,2, 6,7,5,8,
# Initial Image
# #puzzle = 1000, sudoku_acc = 0.999000, label_acc = 0.999937, entropy_loss = 0.000001, alldiff_loss = 1.386252, recon_loss = 0.084167
# #puzzle = 1000, sudoku_acc = 0.998000, label_acc = 0.999875, entropy_loss = 0.000000, alldiff_loss = 1.386209, recon_loss = 0.084107
# #puzzle = 1000, sudoku_acc = 0.999000, label_acc = 0.999937, entropy_loss = 0.000000, alldiff_loss = 1.386252, recon_loss = 0.084418
# #puzzle = 1000, sudoku_acc = 1.000000, label_acc = 1.000000, entropy_loss = 0.000000, alldiff_loss = 1.386295, recon_loss = 0.084108
# puzzle-6399, Iteration 0: total_loss: -1.306443, loss_recon: 0.079852, entropy_cell: 0.000000, entropy_alldiff: 1.386295
# epoch = 5, iter-0, label_acc = 1.000000, sudoku_acc= 1.000000
# 3,2,1,4, 8,7,5,6, 3,2,1,4, 8,7,5,6,
# 1,4,3,2, 6,5,7,8, 1,4,3,2, 6,5,7,8,
# 4,1,2,3, 5,8,6,7, 4,1,2,3, 5,8,6,7,
# 2,3,4,1, 7,6,8,5, 2,3,4,1, 7,6,8,5,
# Initial Image
# #puzzle = 1000, sudoku_acc = 0.999000, label_acc = 0.999937, entropy_loss = 0.000000, alldiff_loss = 1.386252, recon_loss = 0.084423
# puzzle-7039, Iteration 0: total_loss: -1.306554, loss_recon: 0.079742, entropy_cell: 0.000000, entropy_alldiff: 1.386295
# epoch = 5, iter-0, label_acc = 1.000000, sudoku_acc= 1.000000
# 2,4,3,1, 8,5,7,6, 2,4,3,1, 8,5,7,6,
# 3,1,2,4, 6,7,5,8, 3,1,2,4, 6,7,5,8,
# 4,2,1,3, 7,8,6,5, 4,2,1,3, 7,8,6,5,
# 1,3,4,2, 5,6,8,7, 1,3,4,2, 5,6,8,7,
# Initial Image
# #puzzle = 1000, sudoku_acc = 1.000000, label_acc = 1.000000, entropy_loss = 0.000000, alldiff_loss = 1.386295, recon_loss = 0.084220
# #puzzle = 1000, sudoku_acc = 0.999000, label_acc = 0.999937, entropy_loss = 0.000000, alldiff_loss = 1.386252, recon_loss = 0.084491
# #puzzle = 1000, sudoku_acc = 0.998000, label_acc = 0.999875, entropy_loss = 0.000000, alldiff_loss = 1.386209, recon_loss = 0.084206
# #puzzle = 1000, sudoku_acc = 1.000000, label_acc = 1.000000, entropy_loss = 0.000000, alldiff_loss = 1.386295, recon_loss = 0.084078
# #puzzle = 1000, sudoku_acc = 1.000000, label_acc = 1.000000, entropy_loss = 0.000000, alldiff_loss = 1.386295, recon_loss = 0.084241
# puzzle-2729, Iteration 0: total_loss: -1.307854, loss_recon: 0.078441, entropy_cell: 0.000000, entropy_alldiff: 1.386295
# epoch = 6, iter-0, label_acc = 1.000000, sudoku_acc= 1.000000
# 2,4,1,3, 7,6,8,5, 2,4,1,3, 7,6,8,5,
# 3,1,2,4, 5,8,6,7, 3,1,2,4, 5,8,6,7,
# 4,2,3,1, 8,5,7,6, 4,2,3,1, 8,5,7,6,
# 1,3,4,2, 6,7,5,8, 1,3,4,2, 6,7,5,8,
# Initial Image
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-8bd11b8eb603> in <module>
#     353
#     354                     print ("Initial Image")
# --> 355                     show_sudoku(s1_lst[0], s2_lst[0], np.reshape(s_mix_lst[0], (4, 4, 32, 32)), "init")
#     356                     gen_imgs1_numpy = np.concatenate([item.cpu().data.numpy() for item in gen_img_demix[:nums**2,0]])
#     357                     gen_imgs1_numpy = np.reshape(gen_imgs1_numpy, (4, 4, 32, 32))
#
# <ipython-input-52-8bd11b8eb603> in show_sudoku(x1, x2, x_mix, name)
#      87
#      88     #plt.axis("off")
# ---> 89     plt.show()
#      90
#      91 def gen_alldiff_constraints(nums, batch_size):
#
# ~/miniconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     252     """
#     253     global _show
# --> 254     return _show(*args, **kw)
#     255
#     256
#
# ~/miniconda3/envs/pytorch/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ~/miniconda3/envs/pytorch/lib/python3.7/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     302             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     303         else:
# --> 304             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     305             if not format_dict:
#     306                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/miniconda3/envs/pytorch/lib/python3.7/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# </home/dc874/miniconda3/envs/pytorch/lib/python3.7/site-packages/decorator.py:decorator-gen-9> in __call__(self, obj)
#
# ~/miniconda3/envs/pytorch/lib/python3.7/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/miniconda3/envs/pytorch/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/miniconda3/envs/pytorch/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/miniconda3/envs/pytorch/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# ~/miniconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2047                         orientation=orientation,
#    2048                         dryrun=True,
# -> 2049                         **kwargs)
#    2050                     renderer = self.figure._cachedRenderer
#    2051                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# ~/miniconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     521                 cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     522             _png.write_png(renderer._renderer, fh,
# --> 523                             self.figure.dpi, metadata=metadata)
#     524
#     525     def print_to_buffer(self):
#
# KeyboardInterrupt:
